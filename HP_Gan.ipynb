# %%
import numpy as np
import random as rnd
import torch.nn as nn
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from braniac.readers.body import SequenceBodyReader
from braniac.format import SourceFactory
from utils import gradient_penalty

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, z_size, num_layers=2):
        super(Encoder, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, z_size)
    
    def forward(self, input_seq):
        _, hidden = self.gru(input_seq)
        # Prendi solo l'ultimo hidden state dell'ultimo layer
        hidden = hidden[-1]
        z = self.linear(hidden)
        return z

class Decoder(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=2):
        super(Decoder, self).__init__()
        input_size=256
        self.gru = nn.GRU(input_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, output_size)
    
    def forward(self, z, hidden):
        #z = z.unsqueeze(1).repeat(1, hidden.size(1), 1)  # Replica z per ogni passo temporale
        decoder_input = torch.cat((hidden, z), dim=1)  # Concatena z all'input del decoder
        output, _ = self.gru(decoder_input)
        decoded_sequence = self.linear(output)
        return decoded_sequence

class Generator(nn.Module):
    def __init__(self, input_size, hidden_size, z_size, output_size):
        super(Generator, self).__init__()
        self.encoder = Encoder(input_size, hidden_size, z_size)
        self.decoder = Decoder(input_size, hidden_size, output_size)
    
    def forward(self, input_seq, z):
        z_encoded = self.encoder(input_seq)
        decoded_sequence = self.decoder(z, z_encoded)
        return decoded_sequence

# %%
input_size = 75
input_discriminator_size = 2250
output_size = 1500
num_layers = 2
hidden_size = 512
z_size = 128 # Latent value that control predicted poses.
generator = Generator(input_size, hidden_size, z_size, output_size)

# %%
'''
class Generator(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(Generator, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        
        # Forward propagate RNN
        out, _ = self.rnn(x)  
    
        # out: tensor of shape (batch_size, hidden_size)
        # out: (n, 512)
        
        out = self.fc(out)
        # out: (n, 1500)
        out = out.reshape(-1, 20, 75)
        return out
'''
class Discriminator(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size,hidden_size)
        self.fc2 = nn.Linear(hidden_size, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, x):
        x = nn.functional.leaky_relu(self.fc1(x), inplace=False)
        x = nn.functional.leaky_relu(self.fc2(x), inplace=False)
        out = nn.functional.sigmoid(self.fc3(x))
        return out

class Critic(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size,hidden_size)
        self.fc2 = nn.Linear(hidden_size, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, x):
        x = nn.functional.leaky_relu(self.fc1(x), inplace=False)
        x = nn.functional.leaky_relu(self.fc2(x), inplace=False)
        out = self.fc3(x)
        return out

# %%
max_epochs = 300
dataset = "nturgbd"

# input and output information
input_sequence_length = 10
output_sequence_length = 20
sequence_length = input_sequence_length + output_sequence_length
input_size = 75
input_discriminator_size = 2250
output_size = 1500
num_layers = 2
inputs_depth = 512
z_size = 128 # Latent value that control predicted poses.
data_preprocessing = None
LAMBDA_GP = 10


train_data_reader = SequenceBodyReader('splitted_skeleton\\train_map.csv', sequence_length, dataset,skip_frame=0,data_preprocessing=data_preprocessing,random_sequence=False)
# setting up the model
minibatch_size = 16
lr_init = 5e-5

d_lr = lr_init
g_lr = lr_init    
epoch = 0

lossGenerator = []
lossCritic = []
lossDiscriminator = []

z_rand_params = {'low':-0.1, 'high':0.1}
def generate_random(params, shape):
    return np.random.uniform(params['low'], params['high'], size=shape)

generator = Generator(input_size, hidden_size, z_size, output_size)
discriminator = Discriminator(input_discriminator_size, inputs_depth)
critic = Critic(input_discriminator_size, inputs_depth)

opt_disc = optim.Adam(discriminator.parameters(), lr=d_lr, betas=(0.0, 0.9))
opt_gen = optim.Adam(generator.parameters(), lr=g_lr, betas=(0.0, 0.9))
opt_critic = optim.Adam(critic.parameters(), lr=d_lr, betas=(0.0, 0.9))
criterion = nn.BCELoss()

# %%
for epoch in range(max_epochs):
    train_data_reader.reset()
    idx = 0
    while(train_data_reader.has_more()):
     #inizializzo pose
     input_data, _, current_batch_size, _, _ = train_data_reader.next_minibatch(minibatch_size)
     input_data = input_data / np.linalg.norm(input_data)
     real_poses = torch.from_numpy(input_data)
     #input_data = input_data.reshape(-1, sequence_length, input_size)
     prior_poses = real_poses[:, :10, :] 
     future_poses = real_poses[:, 10:, :]    
     
     #genero rumore
     z_data = generate_random(z_rand_params, shape=[current_batch_size, z_size])
     z_data = torch.from_numpy(z_data).float() 
     
     #genero pose
     prior_poses = prior_poses.view(prior_poses.shape[0], prior_poses.shape[1], -1)
     fake_poses = generator(prior_poses, z_data)
     fake_poses = fake_poses.view(fake_poses.shape[0], 20, 75)
     fake_poses = torch.cat((prior_poses, fake_poses), axis=1)

     real_poses = real_poses.view(real_poses.shape[0], -1)
     fake_poses = fake_poses.view(fake_poses.shape[0], -1)
     real_poses.requires_grad_(True)
     fake_poses.requires_grad_(True)

     #Train critic
     critic_real = critic(real_poses).view(-1) 
     critic_fake = critic(fake_poses).view(-1)
     gp = gradient_penalty(critic, real_poses, fake_poses)
     lossC = (-(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP*gp)
     critic.zero_grad()
     lossC.backward(retain_graph=True)
     opt_critic.step() 


     #Train discriminator
     disc_real = discriminator(real_poses).view(-1)
     if(idx==10):
      accuracy_real_poses = torch.mean(disc_real)*100
      print("accuracy_real_poses: %f% ", accuracy_real_poses.item())
     lossD_real = criterion(disc_real, torch.ones_like(disc_real))
     disc_fake = discriminator(fake_poses).view(-1)
     if(idx==10):
      accuracy_fake_poses = torch.mean(disc_fake)*100
      print("accuracy_fake_poses: %f%", accuracy_fake_poses.item()) 
     lossD_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
     lossD = (lossD_real + lossD_fake) / 2
     discriminator.zero_grad()
     lossD.backward(retain_graph=True)
     opt_disc.step()


     #Train generator
     output = critic(fake_poses).view(-1)
     lossG = -torch.mean(output)
     generator.zero_grad()
     lossG.backward()
     opt_gen.step()
     
       
    lossGenerator.append(lossG.item())
    lossCritic.append(lossC.item())
    lossDiscriminator.append(lossD.item())
    

    print(f"Epoch [{epoch}/{max_epochs}] LossC: {lossC:.4f} lossD: {lossD:.4f} loss G: {lossG:.4f}")
# Out:
# Epoch [0/300] LossC: 0.3920 lossD: 0.6413 loss G: 0.1179
# Epoch [1/300] LossC: 0.0872 lossD: 0.6023 loss G: 0.1741
# Epoch [2/300] LossC: 0.0169 lossD: 0.5557 loss G: 0.2549
# Epoch [3/300] LossC: -0.1488 lossD: 0.5046 loss G: 0.3525
# Epoch [4/300] LossC: -0.2987 lossD: 0.4524 loss G: 0.4640
# Epoch [5/300] LossC: -0.4204 lossD: 0.4016 loss G: 0.5768
# Epoch [6/300] LossC: -0.6444 lossD: 0.3550 loss G: 0.7280
# Epoch [7/300] LossC: -0.8026 lossD: 0.3137 loss G: 0.8614
# Epoch [8/300] LossC: -0.9554 lossD: 0.2765 loss G: 1.0084
# Epoch [9/300] LossC: -1.1198 lossD: 0.2441 loss G: 1.1462
# Epoch [10/300] LossC: -1.1645 lossD: 0.2145 loss G: 1.2035
# Epoch [11/300] LossC: -1.2423 lossD: 0.1882 loss G: 1.2739
# Epoch [12/300] LossC: -1.2947 lossD: 0.1641 loss G: 1.3198
# Epoch [13/300] LossC: -1.2948 lossD: 0.1420 loss G: 1.2922
# Epoch [14/300] LossC: -1.3001 lossD: 0.1218 loss G: 1.2861
# Epoch [15/300] LossC: -1.3060 lossD: 0.1032 loss G: 1.2981
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(lossGenerator, label='Loss del Generatore', linestyle='-', color='blue')
plt.plot(lossCritic, label='Loss del Critico', linestyle='-', color='red')
plt.plot(lossDiscriminator, label='Loss del Discriminatore', linestyle='-', color='green')

# Personalizzazione del grafico
plt.xlabel('Epoca')
plt.ylabel('Loss')
plt.title('Andamento delle Loss durante l\'addestramento')
plt.legend()

# Visualizzazione del grafico
plt.grid()
plt.show()

# %%
# Crea un tensore fittizio di dimensione [16, 30, 25, 3] a scopo illustrativo
# Sostituisci questo tensore con i tuoi dati reali

input_data, _, current_batch_size, _, _ = train_data_reader.next_minibatch(minibatch_size)
batch_size = 16
num_poses = 30
num_joints = 25
num_coords = 3
poses_tensor = torch.from_numpy(input_data)

# Seleziona un esempio dal batch
example_index = 0  # Puoi cambiare l'indice per selezionare un esempio diverso
pose_example = poses_tensor[example_index]

# Crea un nuovo grafico
plt.figure(figsize=(10, 6))

# Cicla attraverso le pose
for pose in pose_example:
    x_coords = pose[:, 0]
    y_coords = pose[:, 1]
    
    # Disegna le giunture come punti
    plt.scatter(x_coords, y_coords, marker='o', s=10)
    
    # Collega le giunture con linee
    # Modifica questo ciclo per collegare le giunture in modo significativo
    for i in range(num_joints - 1):
        plt.plot([x_coords[i], x_coords[i + 1]], [y_coords[i], y_coords[i + 1]], 'k-')

# Imposta i limiti dell'asse x e y per garantire che le pose siano completamente visibili
plt.xlim(-1, 1)  # Modifica questi valori in base alle tue esigenze
plt.ylim(-1, 1)

# Imposta il titolo del grafico
plt.title(f'Pose umane - Esempio {example_index}')

# Mostra il grafico
plt.gca().invert_yaxis()  # Inverti l'asse y per corrispondere a una rappresentazione tipica delle pose umane
plt.grid(True)
plt.show()

# %%
input_data, _, current_batch_size, _, _ = train_data_reader.next_minibatch(minibatch_size)
tensor = torch.from_numpy(input_data)
for i in range(tensor.shape[0]):
    # Crea una figura e un set di assi per il batch corrente
    fig, ax = plt.subplots()

    # Itera su ogni scheletro nella sequenza
    for j in range(tensor.shape[1]):
        # Estrai le posizioni x, y, z delle giunture per il batch e lo scheletro corrente
        x = tensor[i, j, :, 0]
        y = tensor[i, j, :, 1]
        z = tensor[i, j, :, 2]

        # Disegna le connessioni tra le giunture
        ax.plot(x, y, z, marker='o')

    # Imposta i limiti degli assi per garantire una visualizzazione corretta
    ax.set_xlim([-1, 1])
    ax.set_ylim([-1, 1])
    #ax.set_zlim([-1, 1])

    # Aggiungi etichette agli assi
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    #ax.set_zlabel('Z')

    # Mostra il grafico per il batch corrente
    plt.show()
